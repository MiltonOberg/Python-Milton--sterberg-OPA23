# %% [markdown]
# ## Exercise - lists

# %% [markdown]
# ## 1.0 Dice rolls (*)
# Simulate 10 dice rolls and append the rolls to a list or use list comprehension.
#
#   a)   sort the list in ascending order (*)
#
#   b)   sort the list in descending order (*)
#
#   c)   find the maximum and minimum value in the list (*)

# %%
import matplotlib.pyplot as plt
import numpy as np
list_throws = []
i = 0
while i < 10:
    throw = np.random.randint(1,7)
    i += 1
    list_throws.append(throw)
list_throws.sort()
list_throws
# Out:
# [2, 2, 3, 3, 3, 3, 5, 5, 6, 6]

# %%
list_throws = []
i = 0
while i < 10:
    throw = np.random.randint(1,7)
    i += 1
    list_throws.append(throw)
list_throws.sort(reverse=True)
list_throws
# Out:
# [6, 6, 6, 5, 5, 4, 3, 3, 2, 1]

# %% [markdown]
# ## 1.1 Food menu (*)
# Create a:
#
#   a)   list with the following elements: "vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor". (*)
#
#   b)   list with the weekdays (*)
#
#   c)   create a food menu with each day corresponding to each food item and print it out. (*)

# %%
food_menu = ["vegetarisk lasagne", "Spaghetti", "Fisk", "Grönsakssoppa", "Pannkakor", "Korv", "Hamburgare"]
weekdays = ["Måndag", "Tisdag", "Onsdag", "Torsdag", "Fredag", "Lördag", "Söndag"]
menu_day = {day: food for day, food in zip(food_menu, weekdays)}
for day in menu_day:
    print(f"{menu_day[day]}: {day} ")
# Out:
# Måndag: vegetarisk lasagne
# Tisdag: Spaghetti
# Onsdag: Fisk
# Torsdag: Grönsakssoppa
# Fredag: Pannkakor
# Lördag: Korv
# Söndag: Hamburgare

# %% [markdown]
# ## 1.2 Squares (*)
#   a)   Use list comprehension to create a list of squares from -10 to 10 (*)
#
#   b)   Plot this list using matplotlib. (*)

# %%
squares = [x for x in range(-10, 11) if x % 2 == 0] #Lambda? ComprehensionList
squares
# Out:
# [-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10]

# %%
plt.plot(squares)
plt.show()

# %% [markdown]
# ## 1.3 Chessboard (**)
#   a)   Create this list using list comprehension: (*)
#
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
#   b)   Create a 2D list to hold the coordinates in a chessboard. (**)

# %%
rader = ["A","B","C","D","E","F","G","H"]
board = [[f"{rad}{kolumn}" for kolumn in range(1, 9)]for rad in rader]
#squares = [x for x in range(-10, 11) if x % 2 == 0]
board
# Out:
# [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8'],
#  ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8'],
#  ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'],
#  ['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8'],
#  ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8'],
#  ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8'],
#  ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8'],
#  ['H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8']]

# %% [markdown]
# ## 1.4 Dice rolls convergence (**)
#
# Simulate:
#
# &nbsp; a) &nbsp; 100 dice rolls and count the number of outcome six. (*)
#
# &nbsp; b) &nbsp; 10, 100, 1000, 10000, 100000, 1000000 dice rolls. Count the number of outcome six in each simulation and store it in a list. Compute the probability of outcome six in each simulation. (**)
#
# &nbsp; c) &nbsp; Use matplotlib to plot this list. (*)

# %%
six_sum = 0
throws = np.random.randint(1, 7, size = 100)
six_sum = sum(1 for n in throws if n == 6)
print(six_sum)
# Out:
# 17

# %%
dice_rolls = 10
while dice_rolls < 1000000: #då är den klar
    throws = np.random.randint(1, 7, size = dice_rolls)
    dice_rolls *= 10
    six_sum = sum(1 for n in throws if n == 6)
    print(six_sum)
# Out:
# 2
# 21
# 161
# 1593
# 16541

# %% [markdown]
# ## 1.5 Monte Carlo simulation (**)
#
# &nbsp; a) Simulate 5000 uniformly distributed points between -1 and 1, $X\sim U(-1,1)$. Now calculate the Euclidean distances between each point and the origin (0,0), $d_i = \sqrt{x_i^2 + y_i^2}$. For $d_i < 1$ plot the point with one color, and for $d_i > 1$ plot the point in another color, $i = \{1,\ldots, 5000\}$.  (**)
#
# &nbsp; b) Calculate the fraction between number of inner points and number of outer points. What do you this will converge to when number of points reaches infinity? (**)

# %%
x = np.random.uniform(-1, 1, 5000)
y = np.random.uniform(-1, 1, 5000)

d = np.sqrt(x**2 + y**2)
    

plt.figure(figsize = (6, 6))

plt.scatter(x[d < 1], y[d < 1], color = "blue", marker = "x", label = "d<1")
plt.scatter(x[d > 1], y[d > 1], marker = "x", color = "red", label = "d>1")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis("equal")
plt.legend(loc = "upper right")
plt.show()

# %% [markdown]
# ## 6. A cute rabbit among two ferocious snakes (**)
#
# There are three identical doors, behind two of them, there are ferocious snakes and behind one of them is a cute little rabbit. Your aim is to pick a door and get the cute rabbit. You start picking one door randomly and suddenly another door opens and snake slithers away *pssss*. Now you have a choice to either stay with your door or change to the remaining door.
#
# <img src="https://github.com/kokchun/assets/blob/main/python/snakes_rabbits.png?raw=true" width = 200>
#
# &nbsp; a) What is your choice and why? (**)
#
# &nbsp; b) Randomly assign which door has the rabbit, and randomly pick an initial door. Now simulate 10, 100, 1000, 10000, 100000, 1000000 times for staying and for switching doors. Calculate the proportion of finding the rabbits for each set of simulations. Plot the results (**)
#
#
# </div>

# %%
#" jag hade bytt dörr och tackat för gratis 33% extra chans"-21 Monty Hall-problem

# %%
door1 = 0
door2 = 0
door3 = 0
i = 10
while i < 1000000:
    rabbit = np.random.randint(1, 4, i)
    if rabbit == 1:
        door1 = rabbit
    elif rabbit == 2:
        door2 = rabbit
    else:
        door3 = rabbit
    i *= 10
    answer = np.random.randint(1, 4)
    if answer == rabbit:
        right_answer = "Won"
    else:
        right_answer = "Lost"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       5 while i < 1000000:
#       6     rabbit = np.random.randint(1, 4, i)
# ----> 7     if rabbit == 1:
#       8         door1 = rabbit
#       9     elif rabbit == 2:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def simulate(times):
    wins = 0

    for n in range(times):
        rabbit = np.random.randint(1, 4)
        choice = np.random.randint(1, 4)
        opens = np.random.choice([door for door in [1, 2, 3] if door != rabbit and door != choice])
       
        new_choice = [door for door in [1, 2, 3] if door != choice and door != opens][0]
        if new_choice == rabbit:
            wins += 1
    return wins/times
        
rounds = [10**n for n in range(1, 7)]
for times in rounds:
    win_rate = simulate(times)
    print(f"If win frequency: {times} times: {win_rate}%")
# Out:
# If win frequency: 10 times: 0.7%
# If win frequency: 100 times: 0.64%
# If win frequency: 1000 times: 0.672%
# If win frequency: 10000 times: 0.6697%
# If win frequency: 100000 times: 0.66604%
# If win frequency: 1000000 times: 0.666458%
